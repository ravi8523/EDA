# %%
list1=['Ram','sita','laxman']
list2=[20,21,22]

dict1={list1[i]:list2[i] for i in range(len(list1))}
dict1
# Out:
# {'Ram': 20, 'sita': 21, 'laxman': 22}

# %%
import numpy as np
import pandas as pd

# %%
file_name="D:\\datasets\\archive (2)\\Car Sales.xlsx - car_data.csv"

# %%
car_ds=pd.read_csv(file_name)

# %%
car_ds
# Out:
#              Car_id        Date Customer Name  Gender  Annual Income  \
# 0      C_CND_000001    1/2/2022     Geraldine    Male          13500
# 1      C_CND_000002    1/2/2022           Gia    Male        1480000
# 2      C_CND_000003    1/2/2022        Gianna    Male        1035000
# 3      C_CND_000004    1/2/2022       Giselle    Male          13500
# 4      C_CND_000005    1/2/2022         Grace    Male        1465000
# ...             ...         ...           ...     ...            ...
# 23901  C_CND_023902  12/31/2023        Martin    Male          13500
# 23902  C_CND_023903  12/31/2023         Jimmy  Female         900000
# 23903  C_CND_023904  12/31/2023          Emma    Male         705000
# 23904  C_CND_023905  12/31/2023      Victoire    Male          13500
# 23905  C_CND_023906  12/31/2023       Donovan    Male        1225000
#
#                                Dealer_Name    Company       Model  \
# 0      Buddy Storbeck's Diesel Service Inc       Ford  Expedition
# ...

# %%
car_ds['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
pd.get_dummies(car_ds['Gender'])
# Out:
#        Female  Male
# 0           0     1
# 1           0     1
# 2           0     1
# 3           0     1
# 4           0     1
# ...       ...   ...
# 23901       0     1
# 23902       1     0
# 23903       0     1
# 23904       0     1
# 23905       0     1
#
# [23906 rows x 2 columns]

# %%
pd.get_dummies(car_ds,columns=['Gender'])
# Out:
#              Car_id        Date Customer Name  Annual Income  \
# 0      C_CND_000001    1/2/2022     Geraldine          13500
# 1      C_CND_000002    1/2/2022           Gia        1480000
# 2      C_CND_000003    1/2/2022        Gianna        1035000
# 3      C_CND_000004    1/2/2022       Giselle          13500
# 4      C_CND_000005    1/2/2022         Grace        1465000
# ...             ...         ...           ...            ...
# 23901  C_CND_023902  12/31/2023        Martin          13500
# 23902  C_CND_023903  12/31/2023         Jimmy         900000
# 23903  C_CND_023904  12/31/2023          Emma         705000
# 23904  C_CND_023905  12/31/2023      Victoire          13500
# 23905  C_CND_023906  12/31/2023       Donovan        1225000
#
#                                Dealer_Name    Company       Model  \
# 0      Buddy Storbeck's Diesel Service Inc       Ford  Expedition
# 1                         C & M Motors Inc      Dodge     Durango
# ...

# %%
car_ds
# Out:
#              Car_id        Date Customer Name  Gender  Annual Income  \
# 0      C_CND_000001    1/2/2022     Geraldine    Male          13500
# 1      C_CND_000002    1/2/2022           Gia    Male        1480000
# 2      C_CND_000003    1/2/2022        Gianna    Male        1035000
# 3      C_CND_000004    1/2/2022       Giselle    Male          13500
# 4      C_CND_000005    1/2/2022         Grace    Male        1465000
# ...             ...         ...           ...     ...            ...
# 23901  C_CND_023902  12/31/2023        Martin    Male          13500
# 23902  C_CND_023903  12/31/2023         Jimmy  Female         900000
# 23903  C_CND_023904  12/31/2023          Emma    Male         705000
# 23904  C_CND_023905  12/31/2023      Victoire    Male          13500
# 23905  C_CND_023906  12/31/2023       Donovan    Male        1225000
#
#                                Dealer_Name    Company       Model  \
# 0      Buddy Storbeck's Diesel Service Inc       Ford  Expedition
# ...

# %%
car_ds
# Out:
#              Car_id        Date Customer Name  Gender  Annual Income  \
# 0      C_CND_000001    1/2/2022     Geraldine    Male          13500
# 1      C_CND_000002    1/2/2022           Gia    Male        1480000
# 2      C_CND_000003    1/2/2022        Gianna    Male        1035000
# 3      C_CND_000004    1/2/2022       Giselle    Male          13500
# 4      C_CND_000005    1/2/2022         Grace    Male        1465000
# ...             ...         ...           ...     ...            ...
# 23901  C_CND_023902  12/31/2023        Martin    Male          13500
# 23902  C_CND_023903  12/31/2023         Jimmy  Female         900000
# 23903  C_CND_023904  12/31/2023          Emma    Male         705000
# 23904  C_CND_023905  12/31/2023      Victoire    Male          13500
# 23905  C_CND_023906  12/31/2023       Donovan    Male        1225000
#
#                                Dealer_Name    Company       Model  \
# 0      Buddy Storbeck's Diesel Service Inc       Ford  Expedition
# ...

# %%
 pd.get_dummies(car_ds,prefix='Ravi',columns=['Gender'])
# Out:
#              Car_id        Date Customer Name  Annual Income  \
# 0      C_CND_000001    1/2/2022     Geraldine          13500
# 1      C_CND_000002    1/2/2022           Gia        1480000
# 2      C_CND_000003    1/2/2022        Gianna        1035000
# 3      C_CND_000004    1/2/2022       Giselle          13500
# 4      C_CND_000005    1/2/2022         Grace        1465000
# ...             ...         ...           ...            ...
# 23901  C_CND_023902  12/31/2023        Martin          13500
# 23902  C_CND_023903  12/31/2023         Jimmy         900000
# 23903  C_CND_023904  12/31/2023          Emma         705000
# 23904  C_CND_023905  12/31/2023      Victoire          13500
# 23905  C_CND_023906  12/31/2023       Donovan        1225000
#
#                                Dealer_Name    Company       Model  \
# 0      Buddy Storbeck's Diesel Service Inc       Ford  Expedition
# 1                         C & M Motors Inc      Dodge     Durango
# ...

# %% [markdown]
# # method 4
#   label encoder

# %%
keys=car_ds['Company'].unique()
values=[i for i in range(len(keys))]
d={keys[i]:values[i] for i in range(len(keys))}
car_ds['Company'].map(d)
# Out:
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
#          ..
# 23901    27
# 23902     6
# 23903     9
# 23904     6
# 23905    26
# Name: Company, Length: 23906, dtype: int64

# %%
file_name="D:\\datasets\\archive (2)\\Car Sales.xlsx - car_data.csv"
car_ds=pd.read_csv(file_name)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
car_ds['Company']=le.fit_transform(car_ds['Company'])

# %%
car_ds
# Out:
#              Car_id        Date Customer Name  Gender  Annual Income  \
# 0      C_CND_000001    1/2/2022     Geraldine    Male          13500
# 1      C_CND_000002    1/2/2022           Gia    Male        1480000
# 2      C_CND_000003    1/2/2022        Gianna    Male        1035000
# 3      C_CND_000004    1/2/2022       Giselle    Male          13500
# 4      C_CND_000005    1/2/2022         Grace    Male        1465000
# ...             ...         ...           ...     ...            ...
# 23901  C_CND_023902  12/31/2023        Martin    Male          13500
# 23902  C_CND_023903  12/31/2023         Jimmy  Female         900000
# 23903  C_CND_023904  12/31/2023          Emma    Male         705000
# 23904  C_CND_023905  12/31/2023      Victoire    Male          13500
# 23905  C_CND_023906  12/31/2023       Donovan    Male        1225000
#
#                                Dealer_Name  Company       Model  \
# 0      Buddy Storbeck's Diesel Service Inc        8  Expedition
# ...

# %%
output[:10]
# Out:
# array([ 8,  7,  4, 27,  0, 18, 27, 18,  5,  8])

# %%
car_ds[['Company','Company_new']]
# Out:
#        Company  Company_new
# 0            8            8
# 1            7            7
# 2            4            4
# 3           27           27
# 4            0            0
# ...        ...          ...
# 23901       21           21
# 23902        5            5
# 23903        2            2
# 23904        5            5
# 23905       14           14
#
# [23906 rows x 2 columns]

# %%
file_name="D:\\datasets\\archive (2)\\Car Sales.xlsx - car_data.csv"
car_ds=pd.read_csv(file_name)
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
car_ds['Company']=le.fit_transform(car_ds['Company'])

# %%
converted=car_ds['Company'].values
original=le.inverse_transform(car_ds['Company'])

# %%
print(converted[:10])
print(original[:10])
# Out:
# [ 8  7  4 27  0 18 27 18  5  8]
# ['Ford' 'Dodge' 'Cadillac' 'Toyota' 'Acura' 'Mitsubishi' 'Toyota'
#  'Mitsubishi' 'Chevrolet' 'Ford']

# %%
file_name="D:\\datasets\\archive (2)\\Car Sales.xlsx - car_data.csv"
car_ds=pd.read_csv(file_name)
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

for i in cat[i:]: 
    car_ds[i]=le.fit_transform(car_ds[i])
car_ds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 6
#       3 from sklearn.preprocessing import LabelEncoder
#       4 le=LabelEncoder()
# ----> 6 for i in cat[i:]:
#       7     car_ds[i]=le.fit_transform(car_ds[i])
#       8 car_ds
#
# NameError: name 'cat' is not defined
